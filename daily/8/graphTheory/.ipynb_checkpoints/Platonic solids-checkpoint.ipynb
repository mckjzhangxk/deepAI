# %%
import networkx as nx
import numpy as np

# %%
def regular_solid():
    G=nx.Graph()
    G.add_edge(1,2)
    G.add_edge(1,5)
    G.add_edge(1,6)
    
    G.add_edge(2,3)
    G.add_edge(2,8)
    
    G.add_edge(3,4)
    G.add_edge(3,10)
    
    G.add_edge(4,5)
    G.add_edge(4,12)
    
    G.add_edge(5,14)
    
    G.add_edge(6,7)
    G.add_edge(6,15)
    
    G.add_edge(7,8)
    G.add_edge(7,17)
    
    G.add_edge(8,9)
    
    G.add_edge(9,10)
    G.add_edge(9,18)
    
    G.add_edge(10,11)
    
    
    G.add_edge(11,12)
    G.add_edge(11,19)
    
    G.add_edge(12,13)
    
    G.add_edge(13,14)
    G.add_edge(13,20)
    
    G.add_edge(14,15)
    
    G.add_edge(15,16)
    
    G.add_edge(16,17)
    G.add_edge(16,20)
    
    G.add_edge(17,18)
    
    G.add_edge(18,19)
    
    G.add_edge(19,20)
    return G
def graph2Matrix(G):
    n=len(G.nodes)
    A=np.zeros((n,n))
    for nodeIdx,adj in G.adjacency():
        for adjIdx,w in adj.items():
            s,t= (nodeIdx-1,adjIdx-1)   
            if s!=t:
                A[s,t]=1 #w['weight'] if 'weight' in w else 1
    return A
def LaplacianMatrix(A):
    D=np.diag(A.sum(axis=1))
    return D-A

# %%
G=regular_solid()
G = nx.random_geometric_graph(200, 0.125)
L=np.array(nx.laplacian_matrix(G).todense())
# L=LaplacianMatrix(A)

# %%
from scipy.linalg import eigh
import matplotlib.pyplot as plt
# %matplotlib inline
w, v = eigh(L) # w = eigenvalues, v = eigen=vectors
n=len(w)
x = v[:,1]
y = v[:,2]
spectral_coordinates = {i : (x[i], y[i]) for i in range(n)}


nx.draw(G,pos=spectral_coordinates,node_size=20)
# nx.draw_networkx_labels(G,pos=spectral_coordinates)
plt.axis('equal')
# Out:
# (-0.0857421483323072,
#  0.1797480675486481,
#  -0.1195846488303369,
#  0.1467647593264595)

# %%
nx.cluster.square_clustering(G)
# Out:
# {0: 0.4356877323420074,
#  1: 0.5544041450777202,
#  2: 0.7870370370370371,
#  3: 0.6176470588235294,
#  4: 0.10458081244598098,
#  5: 0.28502415458937197,
#  6: 0.4666666666666667,
#  7: 0.8082191780821918,
#  8: 0.10266847580280417,
#  9: 0.21914357682619648,
#  10: 0.08108108108108109,
#  11: 0.5964912280701754,
#  12: 0.4,
#  13: 0.09438430311231394,
#  14: 0.12958963282937366,
#  15: 0.2131324004305705,
#  16: 0.0967741935483871,
#  17: 0.1219409282700422,
#  18: 0.23430962343096234,
#  19: 0.09885931558935361,
#  20: 0.2560296846011132,
#  21: 0.20268256333830104,
#  22: 0.31097560975609756,
#  23: 0.12558139534883722,
#  24: 0.037037037037037035,
#  25: 0.22709163346613545,
#  26: 0.20606629143214508,
#  27: 0.1974921630094044,
#  28: 0.06632989237865144,
#  29: 0.10407544627820815,
#  30: 0.030303030303030304,
#  31: 0.19217081850533807,
#  32: 0.10881877022653721,
#  33: 0.1182181610508281,
#  34: 0.36666666666666664,
#  35: 0.12468030690537084,
#  36: 0.14875357580711074,
# ...
