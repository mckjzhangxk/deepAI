# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
from scipy import stats
import matplotlib as mpl
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import hashlib
from scipy.special import factorial,gamma
# %matplotlib inline

# %% [markdown]
# ## 1.1 高维高斯分布
# <img src='image/norm.png' />

# %%
def drawNormDistribution(fig,X,Y,Z,index):
    ax=fig.add_subplot(index,projection='3d')
    ax.plot_surface(X,Y,Z,rstride=2,cstride=2,cmap=cm.Accent)
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
X,Y=np.mgrid[-6:6:100j,-6:6:100j]
fig=plt.figure(figsize=(10,10))
#标准正太分布
Z=(0.5/np.pi)*np.exp(-0.5*(X**2+Y**2))
drawNormDistribution(fig,X,Y,Z,221)
plt.title(r'$ \mu=0,\ \sigma=I$')

# 正太分布,u=1,2
Z=(0.5/np.pi)*np.exp(-0.5*((X-1)**2+(Y-2)**2))
drawNormDistribution(fig,X,Y,Z,222)
plt.title(r'$\mu=[1,2],\ \sigma=I$')
# cov=[3 0,0 1]
Z=(0.5/np.pi/np.sqrt(3))*np.exp(-0.5*((X**2)/3+Y**2))
drawNormDistribution(fig,X,Y,Z,223)
plt.title(r'$ \mu=0,\ \sigma=[3,0,0,1]$')

# cov=[1 0.5,0.5 1]
cov=np.array([[1,.5],[.5,1]])
inv_cov=np.linalg.inv(cov)
Z=(0.5/np.pi/np.sqrt(0.75))*np.exp(-0.5*(inv_cov[0,0]*X**2+inv_cov[1,1]*Y**2+2*inv_cov[0,1]*X*Y))

drawNormDistribution(fig,X,Y,Z,224)
plt.title(r'$ \mu=0,\ \sigma=[1,.5,.5,1]$')
plt.tight_layout()
fig.show()
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py:402: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
N=100000
d=np.random.randn(N,2)
density,edges=np.histogramdd(d,bins=[30,30])
density/=density.max()
print(density.shape)
print('样本总数:',np.sum(density)) #样本总数
X,Y=np.mgrid[0:30:30j,0:30:30j]
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.scatter(X,Y,density,c='r',s=15*density,marker='o')
ax.plot_surface(X,Y,density,cmap=cm.Accent,rstride=2,cstride=2,alpha=0.4,lw=0.75)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.tight_layout()

# %% [markdown]
# ## 2.1 MD5(128位)/SHA1(160位)

# %%
s='This is a sentence,and this is another sentence'
md5=hashlib.sha1()
md5.update(s.encode('utf-8'))
md5str=md5.hexdigest()
print(len(md5str)) #128位数
print(md5str)

# %%
a=np.array([[1,.5],[.5,1]])
np.linalg.inv(a)

# %% [markdown]
# ## 3.2 gamma 函数分布

# %%
N=12
x=np.linspace(0.001,N,1000)
n=np.arange(1,N)
f_gamma=gamma(x)
f_factorial=factorial(n)
fig=plt.figure()
plt.plot(x,f_gamma,label='gamma function')
plt.plot(n+1,f_factorial,'go',label='n!')
plt.legend(loc='upper left')
plt.tight_layout()

# %% [markdown]
# ## 4相关系数

# %%
def dset(flag,N=1000):
    if flag=='linear':
        x = np.random.rand(N)
        y = x*3
    elif flag=='quatratic':
        x = np.linspace(-1, 1, N)
        y = x ** 2
    elif flag=='tan':
        x = np.random.rand(N) * 1.4
        y = np.tan(x)
    elif flag=='gauss':
        x,y=np.random.randn(2,N)
    return x,y
#绕均值旋转
def rotate(x,y,theta=45):
    theta=np.pi*theta/180
    c,s=np.cos(theta),np.sin(theta)
    rotateMatric=np.array([[c,-s],[s,c]])
    v=np.stack((x,y),axis=0) #2xN
    mu=np.mean(v,axis=1,keepdims=True)
    v=v-mu
    v=rotateMatric.dot(v)+mu
#     print(np.mean(v,axis=1))
    return v[0,:],v[1,:]
def calc_pearson(x,y):
    v1,v2=np.std(x),np.std(y)
    return np.cov(np.stack((x,y),axis=1),rowvar=False)[0,1]/v1/v2

# %%
fig=plt.figure()
setName=['linear','quatratic','tan','gauss']
for name in setName:
    plt.figure()
    x,y=dset(flag=name)
    for i in range(5):
        _x,_y=rotate(x,y,i*10)
        p=calc_pearson(_x,_y)
        plt.plot(_x,_y,'o',markerSize=1,label='linear%d:relation %.3f,scipy result:%.3f'%(i,p,stats.pearsonr(_x,_y)[0]))
    plt.legend(loc='upper left')
    plt.tight_layout()

# %% [markdown]
# ## 5股票，移动均线，卷积

# %%
import pandas as pd

# %%
db=pd.read_table('class5/SH600000.txt',skiprows=2,names=['日期','开盘','最高','最低','收盘','成交量','成交额'])
a=db.drop('日期',axis=1)
a.head()
# Out:
#       开盘     最高     最低     收盘        成交量           成交额
# 0  10.44  10.46  10.04  10.06   66191338  1.419984e+09
# 1  10.19  10.29   9.82  10.15  115147943  2.436891e+09
# 2  10.12  10.12   9.88   9.91   96782575  2.034174e+09
# 3   9.88   9.97   9.53   9.63   85236072  1.761801e+09
# 4   9.56   9.83   9.53   9.76   65707646  1.349532e+09

# %%
data=a.values
N=30
stock_max=data[:N,1]
stock_min=data[:N,2]
stock_open=data[:N,0]
stock_close=data[:N,3]
days=np.arange(N)

#简单移动平均线
t=5
weight=np.ones(t)/t
ma_t=np.convolve(stock_close,weight,mode='valid')  #N-t+1,会翻转weight信号
day_t=np.arange(t-1,N) #N-t+1,从t-1天期计算移动平均的
#指数平均
beta=0.5
weight=np.logspace(0,(t-1),t,base=beta)
weight=weight/(np.sum(weight))
exp_t=np.convolve(stock_close,weight,mode='valid')

# %%
plt.figure()
plt.plot(days,stock_close,'ro-',label='close price')
plt.plot(day_t,ma_t,'b-',label='ma5')
plt.plot(day_t,exp_t,'g-',label='exp5')
plt.legend(loc='upper right')
plt.tight_layout(.1)

# %% [markdown]
# # 6.SVD 分解图片

# %%
import PIL.Image as Image

# %%
pic=Image.open('class5/son.png',mode='r')
w,h=pic.size
I=np.array(pic.getdata())
I=I.reshape((h,w,3)).astype(np.uint8)
print(I.shape)
# Out:
# (282, 218, 3)

# %%
R,G,B=I[:,:,0],I[:,:,1],I[:,:,2]

# %%
def pca(I,k):
    U,S,VT=np.linalg.svd(I,full_matrices=False)  #返回mxr,r,rxn的array
    u=U[:,:k] #mxk
    s=np.diag(S[:k]) #kxk
    vt=VT[:k,:] #kxn
    a=u.dot(s).dot(vt)
    a=a.clip(0,255)
    return a.astype(np.uint8)

# %%
for k in range(4,30,4):
    R_k=pca(R,k)
    G_k=pca(G,k)
    B_k=pca(B,k)
    I_k=np.stack((R_k,G_k,B_k),axis=-1)
    plt.figure()
    plt.imshow(I_k)
    plt.title('pca,k='+str(k))
