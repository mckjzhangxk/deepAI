# %%
from SthWrongWithEvalFrcnn import Result_JSON,COCODB
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']=(15,15)

# %%
val_path='/home/zxk/AI/coco/annotations/instances_val2017.json'
cocodb=COCODB(val_path)
# Out:
# loading annotations into memory...
# Done (t=0.90s)
# creating index...
# index created!

# %%
prefix='/home/zxk/AI/coco/val2017'
yolo_path='/home/zxk/AI/coco/bencemark/yolo_result.json'
frcnn_path='/home/zxk/AI/coco/bencemark/frcnnR50C4_result1.json'
frcnn_result=Result_JSON(frcnn_path,prefix,cocodb)
yolo_result=Result_JSON(yolo_path,prefix,cocodb)

# %% [markdown]
# ### some wrong with the evaluation:let first run eval on yolo result and frcnn seperately

# %%
cocodb.doEval(yolo_path)
# Out:
# Loading and preparing results...
# DONE (t=0.53s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=24.99s).
# Accumulating evaluation results...
# DONE (t=2.72s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.332
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.558
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.360
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.157
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.363
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.497
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.377
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.382
# ...

# %%
cocodb.doEval(frcnn_path)
# Out:
# Loading and preparing results...
# DONE (t=0.19s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=20.85s).
# Accumulating evaluation results...
# DONE (t=3.73s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
# ...

# %% [markdown]
# ### so show the result of yolo first

# %%
imageIds=yolo_result.getImageIds()

# %%
N=888
imageid=imageIds[N]
print(imageid)
I=yolo_result[imageid]
plt.figure()
plt.imshow(I)

plt.figure()
I1=frcnn_result[532481]
plt.imshow(I1)
# Out:
# 533958
# [[0.153, 139.213, 162.539, 129.564]]
# total # boxes:1
# [[2.958, 155.056, 160.429, 97.955]]
# total # boxes:1

# %%
#I know what's wrong with my method,We I predict I shuffle the input,so
# annotation become messy (:-
